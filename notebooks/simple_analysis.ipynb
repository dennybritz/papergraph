# %%
# %%bash
#
# pip install pandas numpy gql
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.8/site-packages (1.0.3)
# Requirement already satisfied: numpy in ./.venv/lib/python3.8/site-packages (1.18.3)
# Requirement already satisfied: gql in ./.venv/lib/python3.8/site-packages (0.4.0)
# Requirement already satisfied: pytz>=2017.2 in ./.venv/lib/python3.8/site-packages (from pandas) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in ./.venv/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.10.0 in ./.venv/lib/python3.8/site-packages (from gql) (1.14.0)
# Requirement already satisfied: graphql-core<3,>=2 in ./.venv/lib/python3.8/site-packages (from gql) (2.3.1)
# Requirement already satisfied: promise<3,>=2.0 in ./.venv/lib/python3.8/site-packages (from gql) (2.3)
# Requirement already satisfied: requests<3,>=2.12 in ./.venv/lib/python3.8/site-packages (from gql) (2.23.0)
# Requirement already satisfied: rx<2,>=1.6 in ./.venv/lib/python3.8/site-packages (from graphql-core<3,>=2->gql) (1.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.8/site-packages (from requests<3,>=2.12->gql) (2020.4.5.1)
# Requirement already satisfied: idna<3,>=2.5 in ./.venv/lib/python3.8/site-packages (from requests<3,>=2.12->gql) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in ./.venv/lib/python3.8/site-packages (from requests<3,>=2.12->gql) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in ./.venv/lib/python3.8/site-packages (from requests<3,>=2.12->gql) (3.0.4)
# WARNING: You are using pip version 19.2.3, however version 20.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
import pandas as pd

# %%
# display full columns
pd.set_option("display.max_colwidth", 0)

# %%
# Use a local server
# GRAPHQL_ENDPOINT = "http://localhost:8080/v1/graphql"

# Use the public endpoint
# !! Please be gentle with your queries! 
# !! This is running on a small postgres server that I'm paying for, so please don't overload it with automated scripts. 
# !! Be nice :) As long as you're running queries by hand through notebooks everything should be fine.
GRAPHQL_ENDPOINT = "http://papergraph.dennybritz.com/v1/graphql"

# %%
transport = RequestsHTTPTransport(
    url=GRAPHQL_ENDPOINT,
    use_json=True,
    headers={"Content-type": "application/json"},
    verify=False)

client = Client(
    retries=3,
    transport=transport,
    fetch_schema_from_transport=True)

# %% [markdown]
# # Query the database
#
# Let's get some data. The following code queries the GraphQL endpoint and gets the 2-level citation graph for a specific paper. That is, it gets all papers that are at most 2 hops away. Assuming that each paper on average cites 30 other papers, the result would be 1 + 30 * 30 = ~900 records. Note that the database currently only contains papers labeled as "Computer Science", so cited papers from other fields will not show up.

# %%
# Paper title is matched via sql LIKE, so this can be a substring of the title
PAPER_TITLE = "%Mastering Atari, Go, Chess and Shogi by Planning with a Learned Model%"

# %%
query = gql("""
fragment paper_fields on papers {
  id
  title
  year
  doi_url
  s2_url
  num_citations
}

query papers($title: String!) {
  papers(limit: 1, where: {title: {_like: $title}}, offset: 0) {
    ...paper_fields
    cites(args: {limit_: 100}) {
      ...paper_fields
      cites(args: {limit_: 100}) {
        ...paper_fields
      }
    }
  }
}
""")

# %%
papers = client.execute(query, variable_values={"title": PAPER_TITLE})
root = papers["papers"][0]

# %%
def process_recursively(paper, fn):
    """Helper function to process the recursive graph data structure. It runs a function for each element in the graph"""
    fn(paper)
    if not "cites" in paper:
        return
    for cited_paper in paper["cites"]:
        process_recursively(cited_paper, fn)

# %% [markdown]
# # Create DataFrame
#
# Next, let's create a dataframe of all papers in the graph. Here, duplicates are eliminated.

# %%
# Create a DataFrame of all papers that appear in this subgraph
paper_map = {}
def add_paper(paper):
    fields = { k : paper[k] for k in paper if k != "cites" }
    paper_map[paper["id"]] = fields
process_recursively(root, add_paper)
papers_df = pd.DataFrame.from_records(list(paper_map.values()), index="id")

print(f"{len(papers_df)} unique papers")
papers_df.head()
# Out:
# 650 unique papers
#                                                                                                                                title  \
# id
# c39fb7a46335c23f7529dd6f9f980462fd38653a  Mastering Atari, Go, Chess and Shogi by Planning with a Learned Model
# 0e7638dc16a5e5e9e46c91272bfb9c3dd242ef6d  Between MDPs and Semi-MDPs: A Framework for Temporal Abstraction in Reinforcement Learning
# 036373f17e5e47bcadc289e6c57d61cf5e08fe3d  Hierarchical Solution of Markov Decision Processes using Macro-actions
# 07b6e294c47ef0d72b3229ca6b891dd772adb47d  Theoretical Results on Reinforcement Learning with Temporally Abstract Options
# 15ebe13f0a12e51eae08180690ea025fdae45008  Why PRODIGY/EBL Works
#
#                                           year  \
# id
# c39fb7a46335c23f7529dd6f9f980462fd38653a  2019
# 0e7638dc16a5e5e9e46c91272bfb9c3dd242ef6d  1999
# 036373f17e5e47bcadc289e6c57d61cf5e08fe3d  1998
# 07b6e294c47ef0d72b3229ca6b891dd772adb47d  1998
# 15ebe13f0a12e51eae08180690ea025fdae45008  1990
#
#                                                                                     doi_url  \
# id
# c39fb7a46335c23f7529dd6f9f980462fd38653a
# 0e7638dc16a5e5e9e46c91272bfb9c3dd242ef6d  https://doi.org/10.1016/S0004-3702%2899%2900052-1
# 036373f17e5e47bcadc289e6c57d61cf5e08fe3d
# 07b6e294c47ef0d72b3229ca6b891dd772adb47d  https://doi.org/10.1007/BFb0026709
# 15ebe13f0a12e51eae08180690ea025fdae45008
#
#                                                                                                               s2_url  \
# id
# c39fb7a46335c23f7529dd6f9f980462fd38653a  https://semanticscholar.org/paper/c39fb7a46335c23f7529dd6f9f980462fd38653a
# 0e7638dc16a5e5e9e46c91272bfb9c3dd242ef6d  https://semanticscholar.org/paper/0e7638dc16a5e5e9e46c91272bfb9c3dd242ef6d
# 036373f17e5e47bcadc289e6c57d61cf5e08fe3d  https://semanticscholar.org/paper/036373f17e5e47bcadc289e6c57d61cf5e08fe3d
# 07b6e294c47ef0d72b3229ca6b891dd772adb47d  https://semanticscholar.org/paper/07b6e294c47ef0d72b3229ca6b891dd772adb47d
# 15ebe13f0a12e51eae08180690ea025fdae45008  https://semanticscholar.org/paper/15ebe13f0a12e51eae08180690ea025fdae45008
#
#                                           num_citations
# id
# c39fb7a46335c23f7529dd6f9f980462fd38653a  25
# 0e7638dc16a5e5e9e46c91272bfb9c3dd242ef6d  1622
# 036373f17e5e47bcadc289e6c57d61cf5e08fe3d  228
# 07b6e294c47ef0d72b3229ca6b891dd772adb47d  74
# 15ebe13f0a12e51eae08180690ea025fdae45008  40

# %% [markdown]
# ## Most Popular Papers
#
# The following shows papers with the overall most citations present in this subgraph. These are the popular papers that are somewhat relevant to the root paper.

# %%
papers_df.sort_values("num_citations", ascending=False).head(25)
# Out:
#                                                                                                                                   title  \
# id
# abd1c342495432171beb7ca8fd9551ef13cbd0ff  ImageNet Classification with Deep Convolutional Neural Networks
# 2c03df8b48bf3fa39054345bafabfeff15bfd11d  Deep Residual Learning for Image Recognition
# 13d4c2f76a7c1a4d0a71204e1d5d263a3f5a7986  Random Forests
# 44d2abe2175df8153f465f6c39b68b76a0d40ab9  Long Short-Term Memory
# 97efafdb4a3942ab3efba53ded7413199f79c054  Reinforcement Learning: An Introduction
# 4f607f03272e4d62708f5b2441355f9e005cb452  Convex Optimization
# 2e62d1345b340d5fda3b092c460264b9543bc4b5  Genetic Algorithms in Search Optimization and Machine Learning
# 4b4279db68b16e20fbc56f9d41980a950191d30a  Adaptation in natural and artificial systems
# 162d958ff885f1462aeda91cd72582323fd6a1f4  Gradient-based learning applied to document recognition
# e15cf50aa89fee8535703b9f9512fca5bfc43327  Going deeper with convolutions
# 54e325aee6b2d476bbbb88615ac15e251c6e8214  Generative Adversarial Nets
# e74f9b7f8eec6ba4704c206b93bc8079af3da4bd  ImageNet Large Scale Visual Recognition Challenge
# d2c733e34d48784a37d717fe43d9e93277a8c53e  ImageNet: A large-scale hierarchical image database
# 6a17ebeeb80cd696bc83a288f1a77ddfc1467079  System Identification: Theory for the User
# fa72afa9b2cbc8f0d7b05d52548906610ffbb9c5  Neural Machine Translation by Jointly Learning to Align and Translate
# 111fd833a4ae576cfdbb27d87d2f8fc0640af355  Learning internal representations by error propagation
# 82266f6103bade9005ec555ed06ba20b5210ff22  Gaussian processes for machine learning
# 46eb79e5eec8a4e2b2f5652b66441e8a4c921c3e  Reducing the dimensionality of data with neural networks.
# b07ce649d6f6eb636872527104b0209d3edc8188  Pattern classification and scene analysis
# 71b7178df5d2b112d07e45038cb5637208659ff7  Microsoft COCO: Common Objects in Context
# e0e9a94c4a6ba219e768b4e59f72c18f0a22e23d  Human-level control through deep reinforcement learning
# 0b544dfe355a5070b60986319a3f51fb45d1348e  Learning Phrase Representations using RNN Encoder-Decoder for Statistical Machine Translation
# 9c9d7247f8c51ec5a02b0d911d1d7b9e8160495d  TensorFlow: Large-Scale Machine Learning on Heterogeneous Distributed Systems
# 204e3073870fae3d05bcbc2f6a8e263d9b72e776  Attention is All you Need
# 23ffaa0fe06eae05817f527a47ac3291077f9e58  Rethinking the Inception Architecture for Computer Vision
#
#                                           year  \
# id
# abd1c342495432171beb7ca8fd9551ef13cbd0ff  2012
# 2c03df8b48bf3fa39054345bafabfeff15bfd11d  2016
# 13d4c2f76a7c1a4d0a71204e1d5d263a3f5a7986  2004
# 44d2abe2175df8153f465f6c39b68b76a0d40ab9  1997
# 97efafdb4a3942ab3efba53ded7413199f79c054  2005
# 4f607f03272e4d62708f5b2441355f9e005cb452  2006
# 2e62d1345b340d5fda3b092c460264b9543bc4b5  1989
# 4b4279db68b16e20fbc56f9d41980a950191d30a  1975
# 162d958ff885f1462aeda91cd72582323fd6a1f4  1998
# e15cf50aa89fee8535703b9f9512fca5bfc43327  2015
# 54e325aee6b2d476bbbb88615ac15e251c6e8214  2014
# e74f9b7f8eec6ba4704c206b93bc8079af3da4bd  2015
# d2c733e34d48784a37d717fe43d9e93277a8c53e  2009
# 6a17ebeeb80cd696bc83a288f1a77ddfc1467079  1987
0e9a94c4a6ba219e768b4e59f72c18f0a22e23d
# 0b544dfe355a5070b60986319a3f51fb45d1348e  https://semanticscholar.org/paper/0b544dfe355a5070b60986319a3f51fb45d1348e
# 9c9d7247f8c51ec5a02b0d911d1d7b9e8160495d  https://semanticscholar.org/paper/9c9d7247f8c51ec5a02b0d911d1d7b9e8160495d
# 204e3073870fae3d05bcbc2f6a8e263d9b72e776  https://semanticscholar.org/paper/204e3073870fae3d05bcbc2f6a8e263d9b72e776
# 23ffaa0fe06eae05817f527a47ac3291077f9e58  https://semanticscholar.org/paper/23ffaa0fe06eae05817f527a47ac3291077f9e58
#
#                                           num_citations
# id
# abd1c342495432171beb7ca8fd9551ef13cbd0ff  40246
# 2c03df8b48bf3fa39054345bafabfeff15bfd11d  32655
# 13d4c2f76a7c1a4d0a71204e1d5d263a3f5a7986  24563
# 44d2abe2175df8153f465f6c39b68b76a0d40ab9  20985
# 97efafdb4a3942ab3efba53ded7413199f79c054  18170
# 4f607f03272e4d62708f5b2441355f9e005cb452  16074
# 2e62d1345b340d5fda3b092c460264b9543bc4b5  16067
# 4b4279db68b16e20fbc56f9d41980a950191d30a  15985
# 162d958ff885f1462aeda91cd72582323fd6a1f4  15423
# e15cf50aa89fee8535703b9f9512fca5bfc43327  13348
# 54e325aee6b2d476bbbb88615ac15e251c6e8214  11910
# e74f9b7f8eec6ba4704c206b93bc8079af3da4bd  10959
# d2c733e34d48784a37d717fe43d9e93277a8c53e  10725
# 6a17ebeeb80cd696bc83a288f1a77ddfc1467079  9534
# fa72afa9b2cbc8f0d7b05d52548906610ffbb9c5  9506
# 111fd833a4ae576cfdbb27d87d2f8fc0640af355  9234
# 82266f6103bade9005ec555ed06ba20b5210ff22  8025
# 46eb79e5eec8a4e2b2f5652b66441e8a4c921c3e  7590
# b07ce649d6f6eb636872527104b0209d3edc8188  7391
# 71b7178df5d2b112d07e45038cb5637208659ff7  6938
# e0e9a94c4a6ba219e768b4e59f72c18f0a22e23d  6647
# 0b544dfe355a5070b60986319a3f51fb45d1348e  6619
# 9c9d7247f8c51ec5a02b0d911d1d7b9e8160495d  6558
# 204e3073870fae3d05bcbc2f6a8e263d9b72e776  6271
# 23ffaa0fe06eae05817f527a47ac3291077f9e58  5534

# %% [markdown]
# ## Most cited papers within the subgraph
#
# The following shows papers that are cited most often **within this subgraph**. These papers tend to be more relevant to the root paper.

# %%
from collections import Counter

c = Counter()
process_recursively(root, lambda p: c.update([p["id"]]))
paper_counts_df = pd.DataFrame.from_records(c.most_common(), columns=["id", "subgraph_citation_count"], index="id")
paper_counts_df = pd.concat([papers_df, paper_counts_df], axis=1)
paper_counts_df.sort_values("subgraph_citation_count", ascending=False).head(20)
# Out:
#                                                                                                                                    title  \
# e0e9a94c4a6ba219e768b4e59f72c18f0a22e23d  Human-level control through deep reinforcement learning
# 97efafdb4a3942ab3efba53ded7413199f79c054  Reinforcement Learning: An Introduction
# f82e4ff4f003581330338aaae71f60316e58dd26  The Arcade Learning Environment: An Evaluation Platform for General Agents (Extended Abstract)
# e4257bc131c36504a04382290cbc27ca8bb27813  Action-Conditional Video Prediction using Deep Networks in Atari Games
# c6170fa90d3b2efede5a2e1660cb23e1c824f2ca  Prioritized Experience Replay
# 3b9732bb07dc99bde5e1f9f75251c6ea5039373e  Deep Reinforcement Learning with Double Q-Learning
